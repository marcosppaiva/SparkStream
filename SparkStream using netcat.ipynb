# %% [markdown]
# # Spark Streaming

# %% [markdown]
# ## Simulating TCP / IP data flow

# %%
from pyspark.streaming import StreamingContext

# %%
# Creating a StreamContex with a 1 second interval
ssc = StreamingContext(sc, 1)

# %%
# Creating a DStream for connect to port 9797 in your local machine
lines = ssc.socketTextStream("localhost", 9797)

# %%
# Divide line into words
words = lines.flatMap(lambda line : line.split(" "))

# %%
# Printing the words
words.pprint()

# %%
# Starts data collection and stream processing
ssc.start()
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2020-05-19 14:16:04
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:07
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:08
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:09
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-05-19 14:16:11
# -------------------------------------------
#
# ...

# %%
# Close connection
ssc.stop()
